# %% [markdown]
# <a href="https://colab.research.google.com/github/vedvkandge2000/Deep-Learning-Project/blob/master/RNN_in_Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import os
import torch.nn as nn
import numpy as np
from torch.nn.utils import clip_grad_norm
from torch.optim import lr_scheduler

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class Dictionary(object):
  def __init__(self):
    self.word2idx = {}
    self.idx2word = {}
    self.idx = 0
  
  def add_word(self,word):
    if word not in self.word2idx:
      self.word2idx[word] = self.idx
      self.idx2word[self.idx] = word
      self.idx += 1

  def __len__(self):
    return len(self.word2idx)

# %%
class TextProcess(object):
  def __init__(self):
    self.dictionary = Dictionary()
  
  def get_data(self, path, batch_size=20):
    with open(path, 'r') as f:
      tokens = 0
      for line in f:
        words = line.split() + ['<eos>']
        tokens += len(words)
        for word in words:
          self.dictionary.add_word(word)
    # Create 1-D tensor that contains the index of all the words in file.
    rep_tensor = torch.LongTensor(tokens)
    index = 0
    with open(path, 'r') as f:
      for line in f:
        words = line.split() + ['<eos>']
        for word in words:
          rep_tensor[index] = self.dictionary.word2idx[word]
          index += 1
    # Find out how many batches we need
    num_batches = rep_tensor.shape[0] // batch_size
    # Remove the remainder( filter out the ones that don't fit)
    rep_tensor = rep_tensor[:num_batches*batch_size]
    # retrun (batch_size, new_batches)
    rep_tensor = rep_tensor.view(batch_size, -1)
    return rep_tensor

# %%
embed_size = 128    #Input features to the LSTM
hidden_size = 1024  #Number of LSTM units
num_layers = 1
num_epochs = 100
batch_size = 20
timesteps = 30
learning_rate = 0.002

# %%
corpus = TextProcess()

# %%
rep_tensor = corpus.get_data('/content/alice.txt',batch_size)

# %%
#rep_tensor is the tensor that contains the index of all the words. Each row contains 1659 words by default 
print(rep_tensor.shape)
# Out:
# torch.Size([20, 1484])

# %%
vocab_size = len(corpus.dictionary)
print(vocab_size)
# Out:
# 5290

# %%
num_batches = rep_tensor.shape[1] // timesteps
print(num_batches)
# Out:
# 49

# %%
class TextGenerator(nn.Module):
  def __init__(self, vocab_size, embed_size, hidden_size, num_layers):
    super(TextGenerator, self).__init__()
    self.embed = nn.Embedding(vocab_size, embed_size)  # Convert words to features.
    self.lstm = nn.LSTM(embed_size, hidden_size, num_layers, batch_first=True)
    self.linear = nn.Linear(hidden_size, vocab_size)

  def forward(self,x,h):
    # Persorm word embedding
    x = self.embed(x)
    #Reshape the input tensor
    #x = x.view(batch_size,timesteps,embed_size)
    out, (h, c) = self.lstm(x, h)
    # Reshape the output from (samples,timesteps,output_features) to a shape appropriate for the FC layer 
    # (batch_size*timesteps, hidden_size)
    out = out.reshape(out.size(0)*out.size(1), out.size(2))
    # Decode hidden states of all time steps
    out = self.linear(out)
    return out, (h, c)

# %%
model = TextGenerator(vocab_size, embed_size, hidden_size, num_layers).to(device)

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
exp_lr_schedular = lr_scheduler.StepLR(optimizer, step_size = 20, gamma = 0.1)

# %%
for epoch in range(num_epochs):
    # Set initial hidden and cell states
    states = (torch.zeros(num_layers, batch_size, hidden_size).to(device),
              torch.zeros(num_layers, batch_size, hidden_size).to(device))

    for i in range(0, rep_tensor.size(1) - timesteps, timesteps):
        # Get mini-batch inputs and targets
        inputs = rep_tensor[:, i:i+timesteps]  
        targets = rep_tensor[:, (i+1):(i+1)+timesteps]
        inputs = inputs.to(device)
        targets = targets.to(device)
        
        outputs,_ = model(inputs, states)
        loss = loss_fn(outputs, targets.reshape(-1))

        model.zero_grad()
        loss.backward()
        #Perform Gradient Clipping. clip_value (float or int) is the maximum allowed value of the gradients 
        #The gradients are clipped in the range [-clip_value, clip_value]. This is to prevent the exploding gradient problem
        clip_grad_norm(model.parameters(), 0.5)
        optimizer.step()
        
        step = (i+1) // timesteps
        # exp_lr_schedular.step()
        if step % 100 == 0:
            print ('Epoch [{}/{}], Loss: {:.4f}'
                   .format(epoch+1, num_epochs, loss.item()))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
# Epoch [1/100], Loss: 8.5732
# Epoch [2/100], Loss: 5.9941
# Epoch [3/100], Loss: 5.2025
# Epoch [4/100], Loss: 4.6692
# Epoch [5/100], Loss: 4.1725
# Epoch [6/100], Loss: 3.7642
# Epoch [7/100], Loss: 3.3880
# Epoch [8/100], Loss: 2.8792
# Epoch [9/100], Loss: 2.5074
# Epoch [10/100], Loss: 2.0714
# Epoch [11/100], Loss: 1.7428
# Epoch [12/100], Loss: 1.5906
# Epoch [13/100], Loss: 1.2320
# Epoch [14/100], Loss: 0.9333
# Epoch [15/100], Loss: 0.7256
# Epoch [16/100], Loss: 0.4473
# Epoch [17/100], Loss: 0.3444
# Epoch [18/100], Loss: 0.1986
# Epoch [19/100], Loss: 0.1341
# Epoch [20/100], Loss: 0.0927
# Epoch [21/100], Loss: 0.0777
# Epoch [22/100], Loss: 0.0732
# Epoch [23/100], Loss: 0.0713
# Epoch [24/100], Loss: 0.0692
# Epoch [25/100], Loss: 0.0678
# Epoch [26/100], Loss: 0.0667
# Epoch [27/100], Loss: 0.0657
# Epoch [28/100], Loss: 0.0650
# Epoch [29/100], Loss: 0.0643
# Epoch [30/100], Loss: 0.0638
# Epoch [31/100], Loss: 0.0632
# Epoch [32/100], Loss: 0.0629
# Epoch [33/100], Loss: 0.0624
# Epoch [34/100], Loss: 0.0622
# Epoch [35/100], Loss: 0.0616
# Epoch [36/100], Loss: 0.0616
# Epoch [37/100], Loss: 0.0610
# Epoch [38/100], Loss: 0.0610
# Epoch [39/100], Loss: 0.0604
# Epoch [40/100], Loss: 0.0606
# Epoch [41/100], Loss: 0.0599
# Epoch [42/100], Loss: 0.0601
# Epoch [43/100], Loss: 0.0594
# Epoch [44/100], Loss: 0.0597
# Epoch [45/100], Loss: 0.0590
# Epoch [46/100], Loss: 0.0594
# Epoch [47/100], Loss: 0.0586
# Epoch [48/100], Loss: 0.0590
# Epoch [49/100], Loss: 0.0583
# Epoch [50/100], Loss: 0.0587
# Epoch [51/100], Loss: 0.0580
# Epoch [52/100], Loss: 0.0584
# Epoch [53/100], Loss: 0.0577
# Epoch [54/100], Loss: 0.0581
# Epoch [55/100], Loss: 0.0574
# Epoch [56/100], Loss: 0.0578
# Epoch [57/100], Loss: 0.0571
# Epoch [58/100], Loss: 0.0575
# Epoch [59/100], Loss: 0.0569
# Epoch [60/100], Loss: 0.0572
# Epoch [61/100], Loss: 0.0566
# Epoch [62/100], Loss: 0.0570
# Epoch [63/100], Loss: 0.0563
# Epoch [64/100], Loss: 0.0567
# Epoch [65/100], Loss: 0.0561
# Epoch [66/100], Loss: 0.0565
# Epoch [67/100], Loss: 0.0559
# Epoch [68/100], Loss: 0.0563
# Epoch [69/100], Loss: 0.0556
# Epoch [70/100], Loss: 0.0560
# Epoch [71/100], Loss: 0.0554
# Epoch [72/100], Loss: 0.0558
# Epoch [73/100], Loss: 0.0552
# Epoch [74/100], Loss: 0.0556
# Epoch [75/100], Loss: 0.0550
# Epoch [76/100], Loss: 0.0554
# Epoch [77/100], Loss: 0.0548
# Epoch [78/100], Loss: 0.0552
# Epoch [79/100], Loss: 0.0546
# Epoch [80/100], Loss: 0.0549
# Epoch [81/100], Loss: 0.0543
# Epoch [82/100], Loss: 0.0548
# Epoch [83/100], Loss: 0.0541
# Epoch [84/100], Loss: 0.0545
# Epoch [85/100], Loss: 0.0539
# Epoch [86/100], Loss: 0.0543
# Epoch [87/100], Loss: 0.0537
# Epoch [88/100], Loss: 0.0542
# Epoch [89/100], Loss: 0.0535
# Epoch [90/100], Loss: 0.0539
# Epoch [91/100], Loss: 0.0533
# Epoch [92/100], Loss: 0.0537
# Epoch [93/100], Loss: 0.0531
# Epoch [94/100], Loss: 0.0535
# Epoch [95/100], Loss: 0.0530
# Epoch [96/100], Loss: 0.0533
# Epoch [97/100], Loss: 0.0528
# Epoch [98/100], Loss: 0.0532
# Epoch [99/100], Loss: 0.0526
# Epoch [100/100], Loss: 0.0530

# %%
# Test the model
with torch.no_grad():
    with open('/content/results.txt', 'w') as f:
        # Set intial hidden ane cell states
        state = (torch.zeros(num_layers, 1, hidden_size).to(device),
                 torch.zeros(num_layers, 1, hidden_size).to(device))
        # Select one word id randomly and convert it to shape (1,1)
        input = torch.randint(0,vocab_size, (1,)).long().unsqueeze(1).to(device)

        for i in range(500):
            output, _ = model(input, state)
            print(output.shape)
            # Sample a word id from the exponential of the output 
            prob = output.exp()
            word_id = torch.multinomial(prob, num_samples=1).item()
            print(word_id)
            # Replace the input with sampled word id for the next time step
            input.fill_(word_id)

            # Write the results to file
            word = corpus.dictionary.idx2word[word_id]
            word = '\n' if word == '<eos>' else word + ' '
            f.write(word)
            
            if (i+1) % 100 == 0:
                print('Sampled [{}/{}] words and save to {}'.format(i+1, 500, 'results.txt'))
# Out:
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 2974
# torch.Size([1, 5290])
# 73
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1284
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3289
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 160
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 333
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 933
# torch.Size([1, 5290])
# 366
# torch.Size([1, 5290])
# 367
# torch.Size([1, 5290])
# 3429
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3204
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 427
# torch.Size([1, 5290])
# 11
# torch.Size([1, 5290])
# 1667
# torch.Size([1, 5290])
# 1697
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 11
# torch.Size([1, 5290])
# 1667
# torch.Size([1, 5290])
# 250
# torch.Size([1, 5290])
# 251
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 265
# torch.Size([1, 5290])
# 1909
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 933
# torch.Size([1, 5290])
# 265
# torch.Size([1, 5290])
# 1909
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 80
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1697
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 2812
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 1331
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 80
# torch.Size([1, 5290])
# 1054
# torch.Size([1, 5290])
# 2183
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 38
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 333
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 776
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 3187
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 18
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 1528
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3830
# torch.Size([1, 5290])
# 4145
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 35
# torch.Size([1, 5290])
# 2678
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 384
# torch.Size([1, 5290])
# 4037
# torch.Size([1, 5290])
# 360
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1981
# torch.Size([1, 5290])
# 57
# torch.Size([1, 5290])
# 2073
# torch.Size([1, 5290])
# 1407
# torch.Size([1, 5290])
# 2812
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 366
# torch.Size([1, 5290])
# 367
# torch.Size([1, 5290])
# 134
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 35
# torch.Size([1, 5290])
# 2678
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 1289
# torch.Size([1, 5290])
# 11
# torch.Size([1, 5290])
# 1667
# Sampled [100/500] words and save to results.txt
# torch.Size([1, 5290])
# 30
# torch.Size([1, 5290])
# 16
# torch.Size([1, 5290])
# 390
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 333
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1457
# torch.Size([1, 5290])
# 3607
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 285
# torch.Size([1, 5290])
# 2379
# torch.Size([1, 5290])
# 1264
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 575
# torch.Size([1, 5290])
# 9
# torch.Size([1, 5290])
# 615
# torch.Size([1, 5290])
# 116
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 110
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 4919
# torch.Size([1, 5290])
# 2915
# torch.Size([1, 5290])
# 153
# torch.Size([1, 5290])
# 114
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 2321
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 272
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 2344
# torch.Size([1, 5290])
# 1710
# torch.Size([1, 5290])
# 18
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 4772
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 384
# torch.Size([1, 5290])
# 4037
# torch.Size([1, 5290])
# 265
# torch.Size([1, 5290])
# 1909
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 4160
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1981
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 1228
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 3225
# torch.Size([1, 5290])
# 232
# torch.Size([1, 5290])
# 2127
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 2416
# torch.Size([1, 5290])
# 262
# torch.Size([1, 5290])
# 95
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 303
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 165
# torch.Size([1, 5290])
# 2812
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 887
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 1228
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 1233
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 768
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 2204
# torch.Size([1, 5290])
# 613
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 898
# torch.Size([1, 5290])
# 781
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 333
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 46
# torch.Size([1, 5290])
# 202
# torch.Size([1, 5290])
# 491
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 855
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 5234
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 916
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 1331
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3027
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 898
# Sampled [200/500] words and save to results.txt
# torch.Size([1, 5290])
# 781
# torch.Size([1, 5290])
# 16
# torch.Size([1, 5290])
# 55
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 42
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3387
# torch.Size([1, 5290])
# 804
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 798
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 60
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3475
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 22
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 269
# torch.Size([1, 5290])
# 95
# torch.Size([1, 5290])
# 110
# torch.Size([1, 5290])
# 92
# torch.Size([1, 5290])
# 173
# torch.Size([1, 5290])
# 4451
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 4008
# torch.Size([1, 5290])
# 4184
# torch.Size([1, 5290])
# 674
# torch.Size([1, 5290])
# 38
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 11
# torch.Size([1, 5290])
# 1452
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 165
# torch.Size([1, 5290])
# 1231
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 300
# torch.Size([1, 5290])
# 55
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 80
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 2065
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 668
# torch.Size([1, 5290])
# 2941
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 55
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 3128
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 55
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 362
# torch.Size([1, 5290])
# 208
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1284
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 836
# torch.Size([1, 5290])
# 207
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 333
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 80
# torch.Size([1, 5290])
# 1351
# torch.Size([1, 5290])
# 202
# torch.Size([1, 5290])
# 491
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 768
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 366
# torch.Size([1, 5290])
# 367
# torch.Size([1, 5290])
# 3429
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 512
# torch.Size([1, 5290])
# 272
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 22
# torch.Size([1, 5290])
# 375
# torch.Size([1, 5290])
# 87
# torch.Size([1, 5290])
# 94
# torch.Size([1, 5290])
# 41
# torch.Size([1, 5290])
# 42
# torch.Size([1, 5290])
# 971
# torch.Size([1, 5290])
# 190
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 80
# torch.Size([1, 5290])
# 1054
# torch.Size([1, 5290])
# 4185
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 96
# torch.Size([1, 5290])
# 1274
# torch.Size([1, 5290])
# 167
# Sampled [300/500] words and save to results.txt
# torch.Size([1, 5290])
# 9
# torch.Size([1, 5290])
# 1054
# torch.Size([1, 5290])
# 4185
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 2065
# torch.Size([1, 5290])
# 1378
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 3225
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 1040
# torch.Size([1, 5290])
# 16
# torch.Size([1, 5290])
# 390
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 1933
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1054
# torch.Size([1, 5290])
# 2521
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1457
# torch.Size([1, 5290])
# 3607
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 1637
# torch.Size([1, 5290])
# 4559
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1697
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 150
# torch.Size([1, 5290])
# 114
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 367
# torch.Size([1, 5290])
# 3429
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1054
# torch.Size([1, 5290])
# 2521
# torch.Size([1, 5290])
# 116
# torch.Size([1, 5290])
# 95
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 305
# torch.Size([1, 5290])
# 1148
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1054
# torch.Size([1, 5290])
# 3481
# torch.Size([1, 5290])
# 9
# torch.Size([1, 5290])
# 193
# torch.Size([1, 5290])
# 95
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 285
# torch.Size([1, 5290])
# 1001
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 93
# torch.Size([1, 5290])
# 1388
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 1233
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 2474
# torch.Size([1, 5290])
# 3244
# torch.Size([1, 5290])
# 948
# torch.Size([1, 5290])
# 38
# torch.Size([1, 5290])
# 16
# torch.Size([1, 5290])
# 2756
# torch.Size([1, 5290])
# 2757
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 2416
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 22
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 266
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 3128
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 933
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 150
# torch.Size([1, 5290])
# 114
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 2042
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 333
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 305
# torch.Size([1, 5290])
# 4475
# torch.Size([1, 5290])
# 272
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 333
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 80
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 3127
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 110
# torch.Size([1, 5290])
# 2937
# torch.Size([1, 5290])
# 1000
# Sampled [400/500] words and save to results.txt
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 38
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 2065
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1368
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 402
# torch.Size([1, 5290])
# 403
# torch.Size([1, 5290])
# 2032
# torch.Size([1, 5290])
# 668
# torch.Size([1, 5290])
# 372
# torch.Size([1, 5290])
# 395
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 3077
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 4619
# torch.Size([1, 5290])
# 193
# torch.Size([1, 5290])
# 95
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1981
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 2986
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 836
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 855
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 2304
# torch.Size([1, 5290])
# 3127
# torch.Size([1, 5290])
# 1098
# torch.Size([1, 5290])
# 2246
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 1631
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 46
# torch.Size([1, 5290])
# 1649
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1457
# torch.Size([1, 5290])
# 3607
# torch.Size([1, 5290])
# 285
# torch.Size([1, 5290])
# 2546
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 776
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 855
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 4008
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 4033
# torch.Size([1, 5290])
# 533
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 35
# torch.Size([1, 5290])
# 2678
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 497
# torch.Size([1, 5290])
# 80
# torch.Size([1, 5290])
# 1054
# torch.Size([1, 5290])
# 4185
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 96
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 16
# torch.Size([1, 5290])
# 2756
# torch.Size([1, 5290])
# 2757
# torch.Size([1, 5290])
# 272
# torch.Size([1, 5290])
# 1649
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 285
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 2986
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 80
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 2416
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 532
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1767
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 1001
# torch.Size([1, 5290])
# 41
# torch.Size([1, 5290])
# 42
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 5239
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 2416
# torch.Size([1, 5290])
# 2077
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1237
# Sampled [500/500] words and save to results.txt
